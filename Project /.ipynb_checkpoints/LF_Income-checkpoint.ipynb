# %%
import pandas as pd
import geopandas as gpd

# %%
df = pd.read_csv('data/LF/R13296612_SL140.csv')

# %%
df.shape
# Out:
# (14, 88)

# %%
df.head
# Out:
# <bound method NDFrame.head of       Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0   6037188201  14000US06037188201  Census Tract 1882.01
# 1   6037188202  14000US06037188202  Census Tract 1882.02
# 2   6037189101  14000US06037189101  Census Tract 1891.01
# 3   6037189102  14000US06037189102  Census Tract 1891.02
# 4   6037189201  14000US06037189201  Census Tract 1892.01
# 5   6037189202  14000US06037189202  Census Tract 1892.02
# 6   6037189300  14000US06037189300     Census Tract 1893
# 7   6037190401  14000US06037190401  Census Tract 1904.01
# 8   6037190402  14000US06037190402  Census Tract 1904.02
# 9   6037191201  14000US06037191201  Census Tract 1912.01
# 10  6037195201  14000US06037195201  Census Tract 1952.01
# 11  6037195202  14000US06037195202  Census Tract 1952.02
# 12  6037195300  14000US06037195300     Census Tract 1953
# 13  6037980009  14000US06037980009  Census Tract 9800.09
#
#                                             Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0   Census Tract 1882.01, Los Angeles County, Cali...         ca         140
# 1   Census Tract 1882.02, Los Angeles County, Cali...         ca         140
# 2   Census Tract 1891.01, Los Angeles County, Cali...         ca         140
# 3   Census Tract 1891.02, Los Angeles County, Cali...         ca         140
# 4   Census Tract 1892.01, Los Angeles County, Cali...         ca         140
# 5   Census Tract 1892.02, Los Angeles County, Cali...         ca         140
# 6   Census Tract 1893, Los Angeles County, California         ca         140
# 7   Census Tract 1904.01, Los Angeles County, Cali...         ca         140
# 8   Census Tract 1904.02, Los Angeles County, Cali...         ca         140
# 9   Census Tract 1912.01, Los Angeles County, Cali...         ca         140
# 10  Census Tract 1952.01, Los Angeles County, Cali...         ca         140
# 11  Census Tract 1952.02, Los Angeles County, Cali...         ca         140
# 12  Census Tract 1953, Los Angeles County, California         ca         140
# 13  Census Tract 9800.09, Los Angeles County, Cali...         ca         140
#
#     Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  ...  PCT_SE_A14001_008  \
# 0             0      ACSSF          4266     NaN  ...               3.37
# 1             0      ACSSF          4267     NaN  ...               0.68
# 2             0      ACSSF          4269     NaN  ...               2.81
# 3             0      ACSSF          4270     NaN  ...               3.62
# 4             0      ACSSF          4271     NaN  ...               2.99
# 5             0      ACSSF          4272     NaN  ...               1.39
# 6             0      ACSSF          4273     NaN  ...               0.00
# 7             0      ACSSF          4288     NaN  ...               2.51
# 8             0      ACSSF          4289     NaN  ...               2.71
# 9             0      ACSSF          4300     NaN  ...               3.38
# 10            0      ACSSF          4334     NaN  ...               6.08
# 11            0      ACSSF          4335     NaN  ...               1.84
# 12            0      ACSSF          4336     NaN  ...               2.61
# 13            0      ACSSF          6196     NaN  ...                NaN
#
#     PCT_SE_A14001_009  PCT_SE_A14001_010  PCT_SE_A14001_011  \
# 0                3.98               3.37               6.52
# 1                0.77               2.22               4.27
# 2                1.44              10.26               3.95
# 3                1.40               0.88               5.17
# 4                4.22               4.17               5.15
# 5                2.78               4.34               3.99
# 6                0.61               1.06               3.57
# 7                7.86               3.42               7.86
# 8                5.27               0.51               5.20
# 9                5.46               8.23               6.63
# 10               1.76               3.34               4.56
# 11               0.64               2.48               3.33
# 12               4.23               8.74               1.76
# 13                NaN                NaN                NaN
#
#     PCT_SE_A14001_012  PCT_SE_A14001_013  PCT_SE_A14001_014  \
# 0                9.39              15.46              11.37
# 1                4.53              18.70               8.11
# 2                7.75              11.25              10.41
# 3                8.58              21.20              13.13
# 4               10.96               8.49               8.59
# 5                3.47               7.20              15.26
# 6                5.40               4.18               8.82
# 7                9.45              13.72               7.69
# 8               15.37               7.10              10.69
# 9               12.89               9.94               8.90
# 10               6.57              12.34               6.38
# 11              10.28               9.57              16.80
# 12               9.80              15.86               7.61
# 13                NaN                NaN                NaN
#
#     PCT_SE_A14001_015  PCT_SE_A14001_016  PCT_SE_A14001_017
# 0                6.68              10.49              11.76
# 1               10.08               7.17              29.29
# 2                7.75              14.29               7.90
# 3                9.41               5.48              10.60
# 4                4.73               3.45               3.24
# 5               14.05              11.54              21.60
# 6                5.48              11.25              43.57
# 7                3.36               4.56               1.71
# 8                3.73               1.39               0.73
# 9                0.55               1.60               2.03
# 10              11.25              14.71               9.79
# 11               5.03              10.06              28.84
# 12               6.69               5.21              14.73
# 13                NaN                NaN                NaN
#
# [14 rows x 88 columns]>

# %%
df.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 88 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           14 non-null     int64
#  1   Geo_GEOID          14 non-null     object
#  2   Geo_NAME           14 non-null     object
#  3   Geo_QName          14 non-null     object
#  4   Geo_STUSAB         14 non-null     object
#  5   Geo_SUMLEV         14 non-null     int64
#  6   Geo_GEOCOMP        14 non-null     int64
#  7   Geo_FILEID         14 non-null     object
#  8   Geo_LOGRECNO       14 non-null     int64
#  9   Geo_US             0 non-null      float64
#  10  Geo_REGION         0 non-null      float64
#  11  Geo_DIVISION       0 non-null      float64
#  12  Geo_STATECE        0 non-null      float64
#  13  Geo_STATE          14 non-null     int64
#  14  Geo_COUNTY         14 non-null     int64
#  15  Geo_COUSUB         0 non-null      float64
#  16  Geo_PLACE          0 non-null      float64
#  17  Geo_PLACESE        0 non-null      float64
#  18  Geo_TRACT          14 non-null     int64
#  19  Geo_BLKGRP         0 non-null      float64
#  20  Geo_CONCIT         0 non-null      float64
#  21  Geo_AIANHH         0 non-null      float64
#  22  Geo_AIANHHFP       0 non-null      float64
#  23  Geo_AIHHTLI        0 non-null      float64
#  24  Geo_AITSCE         0 non-null      float64
#  25  Geo_AITS           0 non-null      float64
#  26  Geo_ANRC           0 non-null      float64
#  27  Geo_CBSA           0 non-null      float64
#  28  Geo_CSA            0 non-null      float64
#  29  Geo_METDIV         0 non-null      float64
#  30  Geo_MACC           0 non-null      float64
#  31  Geo_MEMI           0 non-null      float64
#  32  Geo_NECTA          0 non-null      float64
#  33  Geo_CNECTA         0 non-null      float64
#  34  Geo_NECTADIV       0 non-null      float64
#  35  Geo_UA             0 non-null      float64
#  36  Geo_UACP           0 non-null      float64
#  37  Geo_CDCURR         0 non-null      float64
#  38  Geo_SLDU           0 non-null      float64
#  39  Geo_SLDL           0 non-null      float64
#  40  Geo_VTD            0 non-null      float64
#  41  Geo_ZCTA3          0 non-null      float64
#  42  Geo_ZCTA5          0 non-null      float64
#  43  Geo_SUBMCD         0 non-null      float64
#  44  Geo_SDELM          0 non-null      float64
#  45  Geo_SDSEC          0 non-null      float64
#  46  Geo_SDUNI          0 non-null      float64
#  47  Geo_UR             0 non-null      float64
#  48  Geo_PCI            0 non-null      float64
#  49  Geo_TAZ            0 non-null      float64
#  50  Geo_UGA            0 non-null      float64
#  51  Geo_BTTR           0 non-null      float64
#  52  Geo_BTBG           0 non-null      float64
#  53  Geo_PUMA5          0 non-null      float64
#  54  Geo_PUMA1          0 non-null      float64
#  55  SE_A14001_001      14 non-null     int64
#  56  SE_A14001_002      14 non-null     int64
#  57  SE_A14001_003      14 non-null     int64
#  58  SE_A14001_004      14 non-null     int64
#  59  SE_A14001_005      14 non-null     int64
#  60  SE_A14001_006      14 non-null     int64
#  61  SE_A14001_007      14 non-null     int64
#  62  SE_A14001_008      14 non-null     int64
#  63  SE_A14001_009      14 non-null     int64
#  64  SE_A14001_010      14 non-null     int64
#  65  SE_A14001_011      14 non-null     int64
#  66  SE_A14001_012      14 non-null     int64
#  67  SE_A14001_013      14 non-null     int64
#  68  SE_A14001_014      14 non-null     int64
#  69  SE_A14001_015      14 non-null     int64
#  70  SE_A14001_016      14 non-null     int64
#  71  SE_A14001_017      14 non-null     int64
#  72  PCT_SE_A14001_002  13 non-null     float64
#  73  PCT_SE_A14001_003  13 non-null     float64
#  74  PCT_SE_A14001_004  13 non-null     float64
#  75  PCT_SE_A14001_005  13 non-null     float64
#  76  PCT_SE_A14001_006  13 non-null     float64
#  77  PCT_SE_A14001_007  13 non-null     float64
#  78  PCT_SE_A14001_008  13 non-null     float64
#  79  PCT_SE_A14001_009  13 non-null     float64
#  80  PCT_SE_A14001_010  13 non-null     float64
#  81  PCT_SE_A14001_011  13 non-null     float64
#  82  PCT_SE_A14001_012  13 non-null     float64
#  83  PCT_SE_A14001_013  13 non-null     float64
#  84  PCT_SE_A14001_014  13 non-null     float64
#  85  PCT_SE_A14001_015  13 non-null     float64
#  86  PCT_SE_A14001_016  13 non-null     float64
#  87  PCT_SE_A14001_017  13 non-null     float64
# dtypes: float64(59), int64(24), object(5)
# memory usage: 9.8+ KB

# %%
df.Geo_FIPS.head()
# Out:
# 0    6037188201
# 1    6037188202
# 2    6037189101
# 3    6037189102
# 4    6037189201
# Name: Geo_FIPS, dtype: int64

# %%
# Have to conver the FIPS code into strings
df = pd.read_csv(
    'data/LF/R13296612_SL140.csv',
    dtype=
    {
        'Geo_FIPS':str,
        'Geo_STATE':str,
        'Geo_COUNTY': str
    }
)

# %%
df.Geo_FIPS.head()
# Out:
# 0    06037188201
# 1    06037188202
# 2    06037189101
# 3    06037189102
# 4    06037189201
# Name: Geo_FIPS, dtype: object

# %%
df.columns[df.isna().all()].tolist()
# Out:
# ['Geo_US',
#  'Geo_REGION',
#  'Geo_DIVISION',
#  'Geo_STATECE',
#  'Geo_COUSUB',
#  'Geo_PLACE',
#  'Geo_PLACESE',
#  'Geo_BLKGRP',
#  'Geo_CONCIT',
#  'Geo_AIANHH',
#  'Geo_AIANHHFP',
#  'Geo_AIHHTLI',
#  'Geo_AITSCE',
#  'Geo_AITS',
#  'Geo_ANRC',
#  'Geo_CBSA',
#  'Geo_CSA',
#  'Geo_METDIV',
#  'Geo_MACC',
#  'Geo_MEMI',
#  'Geo_NECTA',
#  'Geo_CNECTA',
#  'Geo_NECTADIV',
#  'Geo_UA',
#  'Geo_UACP',
#  'Geo_CDCURR',
#  'Geo_SLDU',
#  'Geo_SLDL',
#  'Geo_VTD',
#  'Geo_ZCTA3',
#  'Geo_ZCTA5',
#  'Geo_SUBMCD',
#  'Geo_SDELM',
#  'Geo_SDSEC',
#  'Geo_SDUNI',
#  'Geo_UR',
#  'Geo_PCI',
#  'Geo_TAZ',
#  'Geo_UGA',
#  'Geo_BTTR',
#  'Geo_BTBG',
#  'Geo_PUMA5',
#  'Geo_PUMA1']

# %%
df=df.dropna(axis=1,how="all")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 45 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Geo_FIPS           14 non-null     object
#  1   Geo_GEOID          14 non-null     object
#  2   Geo_NAME           14 non-null     object
#  3   Geo_QName          14 non-null     object
#  4   Geo_STUSAB         14 non-null     object
#  5   Geo_SUMLEV         14 non-null     int64
#  6   Geo_GEOCOMP        14 non-null     int64
#  7   Geo_FILEID         14 non-null     object
#  8   Geo_LOGRECNO       14 non-null     int64
#  9   Geo_STATE          14 non-null     object
#  10  Geo_COUNTY         14 non-null     object
#  11  Geo_TRACT          14 non-null     int64
#  12  SE_A14001_001      14 non-null     int64
#  13  SE_A14001_002      14 non-null     int64
#  14  SE_A14001_003      14 non-null     int64
#  15  SE_A14001_004      14 non-null     int64
#  16  SE_A14001_005      14 non-null     int64
#  17  SE_A14001_006      14 non-null     int64
#  18  SE_A14001_007      14 non-null     int64
#  19  SE_A14001_008      14 non-null     int64
#  20  SE_A14001_009      14 non-null     int64
#  21  SE_A14001_010      14 non-null     int64
#  22  SE_A14001_011      14 non-null     int64
#  23  SE_A14001_012      14 non-null     int64
#  24  SE_A14001_013      14 non-null     int64
#  25  SE_A14001_014      14 non-null     int64
#  26  SE_A14001_015      14 non-null     int64
#  27  SE_A14001_016      14 non-null     int64
#  28  SE_A14001_017      14 non-null     int64
#  29  PCT_SE_A14001_002  13 non-null     float64
#  30  PCT_SE_A14001_003  13 non-null     float64
#  31  PCT_SE_A14001_004  13 non-null     float64
#  32  PCT_SE_A14001_005  13 non-null     float64
#  33  PCT_SE_A14001_006  13 non-null     float64
#  34  PCT_SE_A14001_007  13 non-null     float64
#  35  PCT_SE_A14001_008  13 non-null     float64
#  36  PCT_SE_A14001_009  13 non-null     float64
#  37  PCT_SE_A14001_010  13 non-null     float64
#  38  PCT_SE_A14001_011  13 non-null     float64
#  39  PCT_SE_A14001_012  13 non-null     float64
#  40  PCT_SE_A14001_013  13 non-null     float64
#  41  PCT_SE_A14001_014  13 non-null     float64
#  42  PCT_SE_A14001_015  13 non-null     float64
#  43  PCT_SE_A14001_016  13 non-null     float64
#  44  PCT_SE_A14001_017  13 non-null     float64
# dtypes: float64(16), int64(21), object(8)
# memory usage: 5.0+ KB

# %%
df.columns
# Out:
# Index(['Geo_FIPS', 'Geo_GEOID', 'Geo_NAME', 'Geo_QName', 'Geo_STUSAB',
#        'Geo_SUMLEV', 'Geo_GEOCOMP', 'Geo_FILEID', 'Geo_LOGRECNO', 'Geo_STATE',
#        'Geo_COUNTY', 'Geo_TRACT', 'SE_A14001_001', 'SE_A14001_002',
#        'SE_A14001_003', 'SE_A14001_004', 'SE_A14001_005', 'SE_A14001_006',
#        'SE_A14001_007', 'SE_A14001_008', 'SE_A14001_009', 'SE_A14001_010',
#        'SE_A14001_011', 'SE_A14001_012', 'SE_A14001_013', 'SE_A14001_014',
#        'SE_A14001_015', 'SE_A14001_016', 'SE_A14001_017', 'PCT_SE_A14001_002',
#        'PCT_SE_A14001_003', 'PCT_SE_A14001_004', 'PCT_SE_A14001_005',
#        'PCT_SE_A14001_006', 'PCT_SE_A14001_007', 'PCT_SE_A14001_008',
#        'PCT_SE_A14001_009', 'PCT_SE_A14001_010', 'PCT_SE_A14001_011',
#        'PCT_SE_A14001_012', 'PCT_SE_A14001_013', 'PCT_SE_A14001_014',
#        'PCT_SE_A14001_015', 'PCT_SE_A14001_016', 'PCT_SE_A14001_017'],
#       dtype='object')

# %%
# Define columns to keep
columns_to_keep = ['Geo_FIPS',
                   'SE_A14001_002',
                   'SE_A14001_003',
                   'SE_A14001_004',
                   'SE_A14001_005',
                   'SE_A14001_006',
                   'SE_A14001_007',
                   'SE_A14001_008',
                   'SE_A14001_009',
                   'SE_A14001_010',
                   'SE_A14001_011',
                   'SE_A14001_012',
                   'SE_A14001_013',
                   'SE_A14001_014',
                   'SE_A14001_015',
                   'SE_A14001_016',
                   'SE_A14001_017',
                  ]

# %%
df2 = df[columns_to_keep]
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Geo_FIPS       14 non-null     object
#  1   SE_A14001_002  14 non-null     int64
#  2   SE_A14001_003  14 non-null     int64
#  3   SE_A14001_004  14 non-null     int64
#  4   SE_A14001_005  14 non-null     int64
#  5   SE_A14001_006  14 non-null     int64
#  6   SE_A14001_007  14 non-null     int64
#  7   SE_A14001_008  14 non-null     int64
#  8   SE_A14001_009  14 non-null     int64
#  9   SE_A14001_010  14 non-null     int64
#  10  SE_A14001_011  14 non-null     int64
#  11  SE_A14001_012  14 non-null     int64
#  12  SE_A14001_013  14 non-null     int64
#  13  SE_A14001_014  14 non-null     int64
#  14  SE_A14001_015  14 non-null     int64
#  15  SE_A14001_016  14 non-null     int64
#  16  SE_A14001_017  14 non-null     int64
# dtypes: int64(16), object(1)
# memory usage: 2.0+ KB

# %%
# Rename the columns 
columns = list(df2)
columns
# Out:
# ['Geo_FIPS',
#  'SE_A14001_002',
#  'SE_A14001_003',
#  'SE_A14001_004',
#  'SE_A14001_005',
#  'SE_A14001_006',
#  'SE_A14001_007',
#  'SE_A14001_008',
#  'SE_A14001_009',
#  'SE_A14001_010',
#  'SE_A14001_011',
#  'SE_A14001_012',
#  'SE_A14001_013',
#  'SE_A14001_014',
#  'SE_A14001_015',
#  'SE_A14001_016',
#  'SE_A14001_017']

# %%
df2.columns = ['FIPS',               
'Less than $10,000',
'$10,000-$14,999',
'$15,000-$19,999',
'$20,000-$24,999',
'$25,000-$29,999',
'$30,000-$34,999',
'$35,000-$39,999',
'$40,000-$44,999',
'$45,000-$49,999',
'$50,000-$59,999',
'$60,000-$74,999',
'$75,000-$99,999',
'$100,000-$124,999',
'$125,000-$149,999',
'$150,000-$199,999',
'More than $200,000']

# %%
# Making sure the data works 
df2.head(10)
# Out:
#           FIPS  Less than $10,000  $10,000-$14,999  $15,000-$19,999  \
# 0  06037188201                 37               92               86
# 1  06037188202                 11               24               28
# 2  06037189101                 51               60               68
# 3  06037189102                 56                9              103
# 4  06037189201                248              176               97
# 5  06037189202                 15               54               25
# 6  06037189300                106               28               36
# 7  06037190401                 60              243               29
# 8  06037190402                102              207               62
# 9  06037191201                 84              181              106
#
#    $20,000-$24,999  $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  \
# 0               66                0               38               61
# 1               29                8               66                8
# 2               41               56               16               37
# 3               76               96               57               70
# 4              152              121               61               58
# 5               31               16               25               16
# 6                0               11               30                0
# 7               92              134              107               44
# 8              124               53               98               37
# 9              108               87               92               55
#
#    $40,000-$44,999  $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  \
# 0               72               61              118              170
# 1                9               26               50               53
# 2               19              135               52              102
# 3               27               17              100              166
# 4               82               81              100              213
# 5               32               50               46               40
# 6                8               14               47               71
# 7              138               60              138              166
# 8               72                7               71              210
# 9               89              134              108              210
#
#    $75,000-$99,999  $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# 0              280                206                121                190
# 1              219                 95                118                 84
# 2              148                137                102                188
# 3              410                254                182                106
# 4              165                167                 92                 67
# 5               83                176                162                133
# 6               55                116                 72                148
# 7              241                135                 59                 80
# 8               97                146                 51                 19
# 9              162                145                  9                 26
#
#    More than $200,000
# 0                 213
# 1                 343
# 2                 104
# 3                 205
# 4                  63
# 5                 249
# 6                 573
# 7                  30
# 8                  10
# 9                  33

# %%
# Doing some stats 
df2.mean()
# Out:
# FIPS                  4.312277e+151
# Less than $10,000      6.821429e+01
# $10,000-$14,999        8.721429e+01
# $15,000-$19,999        5.671429e+01
# $20,000-$24,999        6.057143e+01
# $25,000-$29,999        5.378571e+01
# $30,000-$34,999        4.757143e+01
# $35,000-$39,999        3.921429e+01
# $40,000-$44,999        4.614286e+01
# $45,000-$49,999        5.707143e+01
# $50,000-$59,999        6.978571e+01
# $60,000-$74,999        1.280714e+02
# $75,000-$99,999        1.730714e+02
# $100,000-$124,999      1.447857e+02
# $125,000-$149,999      9.421429e+01
# $150,000-$199,999      1.070714e+02
# More than $200,000     1.857143e+02
# dtype: float64

# %%
# access a single column like df['col_name']
df2.head()
# Out:
#           FIPS  Less than $10,000  $10,000-$14,999  $15,000-$19,999  \
# 0  06037188201                 37               92               86
# 1  06037188202                 11               24               28
# 2  06037189101                 51               60               68
# 3  06037189102                 56                9              103
# 4  06037189201                248              176               97
#
#    $20,000-$24,999  $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  \
# 0               66                0               38               61
# 1               29                8               66                8
# 2               41               56               16               37
# 3               76               96               57               70
# 4              152              121               61               58
#
#    $40,000-$44,999  $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  \
# 0               72               61              118              170
# 1                9               26               50               53
# 2               19              135               52              102
# 3               27               17              100              166
# 4               82               81              100              213
#
#    $75,000-$99,999  $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# 0              280                206                121                190
# 1              219                 95                118                 84
# 2              148                137                102                188
# 3              410                254                182                106
# 4              165                167                 92                 67
#
#    More than $200,000
# 0                 213
# 1                 343
# 2                 104
# 3                 205
# 4                  63

# %%
df2['Less than $10,000'].mean()
# Out:
# 68.21428571428571

# %%
df2.median()
# Out:
# FIPS                  6.037190e+09
# Less than $10,000     5.800000e+01
# $10,000-$14,999       5.800000e+01
# $15,000-$19,999       6.250000e+01
# $20,000-$24,999       5.600000e+01
# $25,000-$29,999       5.450000e+01
# $30,000-$34,999       3.400000e+01
# $35,000-$39,999       3.700000e+01
# $40,000-$44,999       3.050000e+01
# $45,000-$49,999       5.250000e+01
# $50,000-$59,999       6.150000e+01
# $60,000-$74,999       1.420000e+02
# $75,000-$99,999       1.635000e+02
# $100,000-$124,999     1.410000e+02
# $125,000-$149,999     9.350000e+01
# $150,000-$199,999     9.500000e+01
# More than $200,000    1.830000e+02
# dtype: float64

# %%
df2.describe()
# Out:
#        Less than $10,000  $10,000-$14,999  $15,000-$19,999  $20,000-$24,999  \
# count          14.000000        14.000000        14.000000        14.000000
# mean           68.214286        87.214286        56.714286        60.571429
# std            64.033860        80.662811        33.689598        45.925884
# min             0.000000         0.000000         0.000000         0.000000
# 25%            20.500000        25.000000        28.250000        29.500000
# 50%            58.000000        58.000000        62.500000        56.000000
# 75%            95.750000       155.000000        81.500000        88.000000
# max           248.000000       243.000000       106.000000       152.000000
#
#        $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  $40,000-$44,999  \
# count        14.000000        14.000000        14.000000        14.000000
# mean         53.785714        47.571429        39.214286        46.142857
# std          45.861294        33.216572        28.447465        40.220273
# min           0.000000         0.000000         0.000000         0.000000
# 25%          12.250000        23.500000        18.500000        11.500000
# 50%          54.500000        34.000000        37.000000        30.500000
# 75%          86.500000        64.750000        57.250000        72.000000
# max         134.000000       107.000000       100.000000       138.000000
#
#        $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  $75,000-$99,999  \
# count        14.000000        14.000000        14.000000        14.000000
# mean         57.071429        69.785714       128.071429       173.071429
# std          46.242612        38.710322        67.830631       103.010428
# min           0.000000         0.000000         0.000000         0.000000
# 25%          19.250000        47.000000        78.750000       106.500000
# 50%          52.500000        61.500000       142.000000       163.500000
# 75%          76.000000       100.000000       169.000000       223.500000
# max         135.000000       138.000000       213.000000       410.000000
#
#        $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# count          14.000000          14.000000          14.000000
# mean          144.785714          94.214286         107.071429
# std            63.857026          56.955014          70.688335
# min             0.000000           0.000000           0.000000
# 25%           110.000000          62.000000          68.750000
# 50%           141.000000          93.500000          95.000000
# 75%           173.750000         120.250000         146.500000
# max           254.000000         185.000000         242.000000
#
#        More than $200,000
# count           14.000000
# mean           185.714286
# std            167.479243
# min              0.000000
# 25%             40.500000
# 50%            183.000000
# 75%            240.000000
# max            573.000000

# %%
df2.plot.bar(title = "Los Feliz")
# Out:
# <AxesSubplot: title={'center': 'Los Feliz'}>

# %%
# Want to create a total households population
df3 = ['Less than $10,000',
'$10,000-$14,999',
'$15,000-$19,999',
'$20,000-$24,999',
'$25,000-$29,999',
'$30,000-$34,999',
'$35,000-$39,999',
'$40,000-$44,999',
'$45,000-$49,999',
'$50,000-$59,999',
'$60,000-$74,999',
'$75,000-$99,999',
'$100,000-$124,999',
'$125,000-$149,999',
'$150,000-$199,999',
'More than $200,000']

# %%
df2['TotalPop'] = df2[df3].sum(axis = 1)
df2.head(3)
# Out:
# /tmp/ipykernel_2083/337586398.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['TotalPop'] = df2[df3].sum(axis = 1)
#           FIPS  Less than $10,000  $10,000-$14,999  $15,000-$19,999  \
# 0  06037188201                 37               92               86
# 1  06037188202                 11               24               28
# 2  06037189101                 51               60               68
#
#    $20,000-$24,999  $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  \
# 0               66                0               38               61
# 1               29                8               66                8
# 2               41               56               16               37
#
#    $40,000-$44,999  $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  \
# 0               72               61              118              170
# 1                9               26               50               53
# 2               19              135               52              102
#
#    $75,000-$99,999  $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# 0              280                206                121                190
# 1              219                 95                118                 84
# 2              148                137                102                188
#
#    More than $200,000  TotalPop
# 0                 213      1811
# 1                 343      1171
# 2                 104      1316

# %%
# Notice that the SE_A14001_001 is household number of resondents by census tract
df3 = pd.read_csv("data/LF/R13296612_SL140.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
df3.head(5)
# Out:
#      Geo_FIPS           Geo_GEOID              Geo_NAME  \
# 0  6037188201  14000US06037188201  Census Tract 1882.01
# 1  6037188202  14000US06037188202  Census Tract 1882.02
# 2  6037189101  14000US06037189101  Census Tract 1891.01
# 3  6037189102  14000US06037189102  Census Tract 1891.02
# 4  6037189201  14000US06037189201  Census Tract 1892.01
#
#                                            Geo_QName Geo_STUSAB  Geo_SUMLEV  \
# 0  Census Tract 1882.01, Los Angeles County, Cali...         ca         140
# 1  Census Tract 1882.02, Los Angeles County, Cali...         ca         140
# 2  Census Tract 1891.01, Los Angeles County, Cali...         ca         140
# 3  Census Tract 1891.02, Los Angeles County, Cali...         ca         140
# 4  Census Tract 1892.01, Los Angeles County, Cali...         ca         140
#
#    Geo_GEOCOMP Geo_FILEID  Geo_LOGRECNO  Geo_US  Geo_REGION  Geo_DIVISION  \
# 0            0      ACSSF          4266     NaN         NaN           NaN
# 1            0      ACSSF          4267     NaN         NaN           NaN
# 2            0      ACSSF          4269     NaN         NaN           NaN
# 3            0      ACSSF          4270     NaN         NaN           NaN
# 4            0      ACSSF          4271     NaN         NaN           NaN
#
#    Geo_STATECE  Geo_STATE  Geo_COUNTY  Geo_COUSUB  Geo_PLACE  Geo_PLACESE  \
# 0          NaN          6          37         NaN        NaN          NaN
# 1          NaN          6          37         NaN        NaN          NaN
# 2          NaN          6          37         NaN        NaN          NaN
# 3          NaN          6          37         NaN        NaN          NaN
# 4          NaN          6          37         NaN        NaN          NaN
#
#    Geo_TRACT  Geo_BLKGRP  Geo_CONCIT  Geo_AIANHH  Geo_AIANHHFP  Geo_AIHHTLI  \
# 0     188201         NaN         NaN         NaN           NaN          NaN
# 1     188202         NaN         NaN         NaN           NaN          NaN
# 2     189101         NaN         NaN         NaN           NaN          NaN
# 3     189102         NaN         NaN         NaN           NaN          NaN
# 4     189201         NaN         NaN         NaN           NaN          NaN
#
#    Geo_AITSCE  Geo_AITS  Geo_ANRC  Geo_CBSA  Geo_CSA  Geo_METDIV  Geo_MACC  \
# 0         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 1         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 2         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 3         NaN       NaN       NaN       NaN      NaN         NaN       NaN
# 4         NaN       NaN       NaN       NaN      NaN         NaN       NaN
#
#    Geo_MEMI  Geo_NECTA  Geo_CNECTA  Geo_NECTADIV  Geo_UA  Geo_UACP  \
# 0       NaN        NaN         NaN           NaN     NaN       NaN
# 1       NaN        NaN         NaN           NaN     NaN       NaN
# 2       NaN        NaN         NaN           NaN     NaN       NaN
# 3       NaN        NaN         NaN           NaN     NaN       NaN
# 4       NaN        NaN         NaN           NaN     NaN       NaN
#
#    Geo_CDCURR  Geo_SLDU  Geo_SLDL  Geo_VTD  Geo_ZCTA3  Geo_ZCTA5  Geo_SUBMCD  \
# 0         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 1         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 2         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 3         NaN       NaN       NaN      NaN        NaN        NaN         NaN
# 4         NaN       NaN       NaN      NaN        NaN        NaN         NaN
#
#    Geo_SDELM  Geo_SDSEC  Geo_SDUNI  Geo_UR  Geo_PCI  Geo_TAZ  Geo_UGA  \
# 0        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 1        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 2        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 3        NaN        NaN        NaN     NaN      NaN      NaN      NaN
# 4        NaN        NaN        NaN     NaN      NaN      NaN      NaN
#
#    Geo_BTTR  Geo_BTBG  Geo_PUMA5  Geo_PUMA1  SE_A14001_001  SE_A14001_002  \
# 0       NaN       NaN        NaN        NaN           1811             37
# 1       NaN       NaN        NaN        NaN           1171             11
# 2       NaN       NaN        NaN        NaN           1316             51
# 3       NaN       NaN        NaN        NaN           1934             56
# 4       NaN       NaN        NaN        NaN           1943            248
#
#    SE_A14001_003  SE_A14001_004  SE_A14001_005  SE_A14001_006  SE_A14001_007  \
# 0             92             86             66              0             38
# 1             24             28             29              8             66
# 2             60             68             41             56             16
# 3              9            103             76             96             57
# 4            176             97            152            121             61
#
#    SE_A14001_008  SE_A14001_009  SE_A14001_010  SE_A14001_011  SE_A14001_012  \
# 0             61             72             61            118            170
# 1              8              9             26             50             53
# 2             37             19            135             52            102
# 3             70             27             17            100            166
# 4             58             82             81            100            213
#
#    SE_A14001_013  SE_A14001_014  SE_A14001_015  SE_A14001_016  SE_A14001_017  \
# 0            280            206            121            190            213
# 1            219             95            118             84            343
# 2            148            137            102            188            104
# 3            410            254            182            106            205
# 4            165            167             92             67             63
#
#    PCT_SE_A14001_002  PCT_SE_A14001_003  PCT_SE_A14001_004  PCT_SE_A14001_005  \
# 0               2.04               5.08               4.75               3.64
# 1               0.94               2.05               2.39               2.48
# 2               3.88               4.56               5.17               3.12
# 3               2.90               0.47               5.33               3.93
# 4              12.76               9.06               4.99               7.82
#
#    PCT_SE_A14001_006  PCT_SE_A14001_007  PCT_SE_A14001_008  PCT_SE_A14001_009  \
# 0               0.00               2.10               3.37               3.98
# 1               0.68               5.64               0.68               0.77
# 2               4.26               1.22               2.81               1.44
# 3               4.96               2.95               3.62               1.40
# 4               6.23               3.14               2.99               4.22
#
#    PCT_SE_A14001_010  PCT_SE_A14001_011  PCT_SE_A14001_012  PCT_SE_A14001_013  \
# 0               3.37               6.52               9.39              15.46
# 1               2.22               4.27               4.53              18.70
# 2              10.26               3.95               7.75              11.25
# 3               0.88               5.17               8.58              21.20
# 4               4.17               5.15              10.96               8.49
#
#    PCT_SE_A14001_014  PCT_SE_A14001_015  PCT_SE_A14001_016  PCT_SE_A14001_017
# 0              11.37               6.68              10.49              11.76
# 1               8.11              10.08               7.17              29.29
# 2              10.41               7.75              14.29               7.90
# 3              13.13               9.41               5.48              10.60
# 4               8.59               4.73               3.45               3.24

# %%
df_householdsize = df3['SE_A14001_001']
df_householdsize.sample(10)
# Out:
# 5     1153
# 12    1419
# 3     1934
# 7     1756
# 1     1171
# 10    1645
# 6     1315
# 8     1366
# 11    1411
# 13       0
# Name: SE_A14001_001, dtype: int64

# %%
df_householdsize.describe()
# Out:
# count      14.000000
# mean     1419.214286
# std       486.140875
# min         0.000000
# 25%      1315.250000
# 50%      1415.000000
# 75%      1728.250000
# max      1943.000000
# Name: SE_A14001_001, dtype: float64

# %%
# Creating a poverty column variable 
df2['poverty'] = df2['Less than $10,000'] + df2['$10,000-$14,999'] + df2['$15,000-$19,999'] + df2['$20,000-$24,999'] 
df2.sample(5)
# Out:
# /tmp/ipykernel_2083/3305094393.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['poverty'] = df2['Less than $10,000'] + df2['$10,000-$14,999'] + df2['$15,000-$19,999'] + df2['$20,000-$24,999']
#            FIPS  Less than $10,000  $10,000-$14,999  $15,000-$19,999  \
# 3   06037189102                 56                9              103
# 10  06037195201                 99               56               63
# 5   06037189202                 15               54               25
# 4   06037189201                248              176               97
# 12  06037195300                 86               16               68
#
#     $20,000-$24,999  $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  \
# 3                76               96               57               70
# 10               56               85               23              100
# 5                31               16               25               16
# 4               152              121               61               58
# 12               56               67               30               37
#
#     $40,000-$44,999  $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  \
# 3                27               17              100              166
# 10               29               55               75              108
# 5                32               50               46               40
# 4                82               81              100              213
# 12               60              124               25              139
#
#     $75,000-$99,999  $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# 3               410                254                182                106
# 10              203                105                185                242
# 5                83                176                162                133
# 4               165                167                 92                 67
# 12              225                108                 95                 74
#
#     More than $200,000  TotalPop  poverty
# 3                  205      1934      244
# 10                 161      1645      274
# 5                  249      1153      125
# 4                   63      1943      673
# 12                 209      1419      226

# %%
#Creating a poverty and total population to get a percent 
df2['p_poverty'] = df2['poverty']/df2['TotalPop']*100
df2.sample(10)
# Out:
# /tmp/ipykernel_2083/3666134208.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['p_poverty'] = df2['poverty']/df2['TotalPop']*100
#            FIPS  Less than $10,000  $10,000-$14,999  $15,000-$19,999  \
# 13  06037980009                  0                0                0
# 10  06037195201                 99               56               63
# 7   06037190401                 60              243               29
# 0   06037188201                 37               92               86
# 11  06037195202                  0               75               23
# 3   06037189102                 56                9              103
# 5   06037189202                 15               54               25
# 2   06037189101                 51               60               68
# 9   06037191201                 84              181              106
# 8   06037190402                102              207               62
#
#     $20,000-$24,999  $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  \
# 13                0                0                0                0
# 10               56               85               23              100
# 7                92              134              107               44
# 0                66                0               38               61
# 11               17               19               23               26
# 3                76               96               57               70
# 5                31               16               25               16
# 2                41               56               16               37
# 9               108               87               92               55
# 8               124               53               98               37
#
#     $40,000-$44,999  $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  \
# 13                0                0                0                0
# 10               29               55               75              108
# 7               138               60              138              166
# 0                72               61              118              170
# 11                9               35               47              145
# 3                27               17              100              166
# 5                32               50               46               40
# 2                19              135               52              102
# 9                89              134              108              210
# 8                72                7               71              210
#
#     $75,000-$99,999  $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# 13                0                  0                  0                  0
# 10              203                105                185                242
# 7               241                135                 59                 80
# 0               280                206                121                190
# 11              135                237                 71                142
# 3               410                254                182                106
# 5                83                176                162                133
# 2               148                137                102                188
# 9               162                145                  9                 26
# 8                97                146                 51                 19
#
#     More than $200,000  TotalPop  poverty  p_poverty
# 13                   0         0        0        NaN
# 10                 161      1645      274  16.656535
# 7                   30      1756      424  24.145786
# 0                  213      1811      281  15.516289
# 11                 407      1411      115   8.150248
# 3                  205      1934      244  12.616339
# 5                  249      1153      125  10.841284
# 2                  104      1316      220  16.717325
# 9                   33      1629      479  29.404543
# 8                   10      1366      495  36.237189

# %%
df2['p_poverty'].plot.hist(bins=50)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# top 10 census of households income that live in poverty. 
df_sorted = df2.sort_values(by='p_poverty',ascending = False)
df_sorted[['FIPS','p_poverty']].head(10)
# Out:
#            FIPS  p_poverty
# 8   06037190402  36.237189
# 4   06037189201  34.637159
# 9   06037191201  29.404543
# 7   06037190401  24.145786
# 2   06037189101  16.717325
# 10  06037195201  16.656535
# 12  06037195300  15.926709
# 0   06037188201  15.516289
# 6   06037189300  12.927757
# 3   06037189102  12.616339

# %%
df_sorted.head(10).plot.bar(x='FIPS',
                            y='p_poverty')
# Out:
# <AxesSubplot: xlabel='FIPS'>

# %%
df_sorted.head(30).plot.barh(x='FIPS',  # barh turns the plot direction 
                            y='p_poverty', 
                            title='Census Tract where Boyle Heights has more poverty',
                            color='Purple')
# Out:
# <AxesSubplot: title={'center': 'Census Tract where Boyle Heights has more poverty'}, ylabel='FIPS'>

# %%
# Import geojson file of LA County
tracts=gpd.read_file('data/LF/Census_Tracts_2020.geojson')
tracts.head(2)
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0         1  101110  1011.10  1.229562e+07   15083.854287
# 1         2  101122  1011.22  2.845774e+07   31671.455844
#
#                                             geometry
# 0  POLYGON ((-118.28491 34.25948, -118.28492 34.2...
# 1  POLYGON ((-118.29015 34.27417, -118.29015 34.2...

# %%
tracts['FIPS'] ='06' + '037' + tracts['CT20']

# %%
tracts=tracts.merge(df2, on="FIPS")

# %%
tracts.head(3)
# Out:
#    OBJECTID    CT20    LABEL   ShapeSTArea  ShapeSTLength  \
# 0       435  188201  1882.01  8.354826e+06   17041.606203
# 1       436  188202  1882.02  8.177322e+06   11794.883592
# 2       438  189101  1891.01  4.254115e+06    8256.537441
#
#                                             geometry         FIPS  \
# 0  POLYGON ((-118.26762 34.11247, -118.26773 34.1...  06037188201
# 1  POLYGON ((-118.28415 34.11250, -118.28309 34.1...  06037188202
# 2  POLYGON ((-118.28743 34.10769, -118.28889 34.1...  06037189101
#
#    Less than $10,000  $10,000-$14,999  $15,000-$19,999  $20,000-$24,999  \
# 0                 37               92               86               66
# 1                 11               24               28               29
# 2                 51               60               68               41
#
#    $25,000-$29,999  $30,000-$34,999  $35,000-$39,999  $40,000-$44,999  \
# 0                0               38               61               72
# 1                8               66                8                9
# 2               56               16               37               19
#
#    $45,000-$49,999  $50,000-$59,999  $60,000-$74,999  $75,000-$99,999  \
# 0               61              118              170              280
# 1               26               50               53              219
# 2              135               52              102              148
#
#    $100,000-$124,999  $125,000-$149,999  $150,000-$199,999  \
# 0                206                121                190
# 1                 95                118                 84
# 2                137                102                188
#
#    More than $200,000  TotalPop  poverty  p_poverty
# 0                 213      1811      281  15.516289
# 1                 343      1171       92   7.856533
# 2                 104      1316      220  16.717325

# %%
# scheme='NaturalBreaks'
tracts.plot(figsize=(12,10),
                 column='p_poverty',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot: >
